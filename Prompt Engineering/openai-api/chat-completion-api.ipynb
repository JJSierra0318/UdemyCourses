# %% [markdown]
# # Your First API Call - `client.chat.completions.create()`
#
# With our environment securely configured, it's time to make our first live API call. This is the moment where the theory becomes practice.
#
# The workhorse function for nearly all chat-based interactions is `client.chat.completions.create()`. This name tells us exactly what it does: using our authenticated `client`, we are asking to `create` a `completion` for a `chat`.
#
# > Note: While we are focusing on the `chat.completions` endpoint, the OpenAI platform offers other powerful tools like `embeddings` for text-to-vector conversion (used in RAG), `images` for DALL-E image generation, and `audio` for speech-to-text. To keep it focused, we will be focusing exclusively on chat in this course.
# >
#
# For this first call, we only need to provide the two most important, required parameters: `model` and `messages`. Let's see how they work.

# %% [markdown]
# ## Secure Setup and Imports
#
# First, let's repeat our secure setup process. We'll import the necessary libraries and load our API key from the `.env` file. This should be the standard starting point for all your projects.

# %%
import openai
from dotenv import load_dotenv

load_dotenv()

print("Libraries imported and env vars loaded.")
# Out:
# Libraries imported and env vars loaded.

# %% [markdown]
# ## Making the API Call
#
# Now for the main event. We will construct our first API call, providing the two essential arguments.
#
# - **`model`**: We'll use `"gpt-4o-mini"`, which is a fantastic and cost-effective model for a wide range of tasks.
# - **`messages`**: This must be a list of dictionaries. For a simple, single-turn request, we'll have just one dictionary in our list with the `role` set to `"user"`.
#
# Let's ask a simple question and see the response.

# %%
MODEL_NAME = "gpt-4o-mini"


client = openai.OpenAI()

response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {
            "role": "user",
            "content": "what is the most relevant skill for a developer?"
        }    
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# The most relevant skill for a developer can vary based on their specific role, the technology stack they work with, and industry demands. However, a few universally important skills include:
#
# 1. **Problem Solving**: The ability to analyze issues and develop efficient solutions is fundamental in programming.
#
# 2. **Proficiency in Programming Languages**: Mastery of at least one programming language (like JavaScript, Python, Java, C#, etc.) is crucial. The choice of language often depends on the area of development (web, mobile, backend, etc.).
#
# 3. **Version Control/Git**: Familiarity with version control systems like Git is essential for collaborating with other developers and managing code changes.
#
# 4. **Understanding of Algorithms and Data Structures**: A solid grasp of algorithms and data structures enhances problem-solving skills and is often tested in technical interviews.
#
# 5. **Familiarity with Frameworks and Libraries**: Knowledge of relevant frameworks (like React, Angular, Django, or Spring) can significantly enhance development efficiency.
#
# 6. **Database Management**: Understanding relational and non-relational databases (like SQL, MongoDB) is key for data-driven applications.
#
# 7. **Software Development Methodologies**: Familiarity with Agile, Scrum, or other methodologies helps in working more effectively within teams.
#
# 8. **Communication Skills**: Being able to communicate technical information to non-technical stakeholders and effectively collaborate with team members is vital.
#
# 9. **Continuous Learning**: The tech industry evolves rapidly, so a commitment to ongoing education and keeping up with industry trends is crucial.
#
# While these skills are generally important, specific needs may vary by employer or project, so it's beneficial to continually assess and adapt your skill set accordingly.

# %%
from IPython.display import display, Markdown

display(Markdown(response.choices[0].message.content))
# Out:
# The most relevant skill for a developer can vary based on their specific role, the technology stack they work with, and industry demands. However, a few universally important skills include:
#
# 1. **Problem Solving**: The ability to analyze issues and develop efficient solutions is fundamental in programming.
#
# 2. **Proficiency in Programming Languages**: Mastery of at least one programming language (like JavaScript, Python, Java, C#, etc.) is crucial. The choice of language often depends on the area of development (web, mobile, backend, etc.).
#
# 3. **Version Control/Git**: Familiarity with version control systems like Git is essential for collaborating with other developers and managing code changes.
#
# 4. **Understanding of Algorithms and Data Structures**: A solid grasp of algorithms and data structures enhances problem-solving skills and is often tested in technical interviews.
#
# 5. **Familiarity with Frameworks and Libraries**: Knowledge of relevant frameworks (like React, Angular, Django, or Spring) can significantly enhance development efficiency.
#
# 6. **Database Management**: Understanding relational and non-relational databases (like SQL, MongoDB) is key for data-driven applications.
#
# 7. **Software Development Methodologies**: Familiarity with Agile, Scrum, or other methodologies helps in working more effectively within teams.
#
# 8. **Communication Skills**: Being able to communicate technical information to non-technical stakeholders and effectively collaborate with team members is vital.
#
# 9. **Continuous Learning**: The tech industry evolves rapidly, so a commitment to ongoing education and keeping up with industry trends is crucial.
#
# While these skills are generally important, specific needs may vary by employer or project, so it's beneficial to continually assess and adapt your skill set accordingly.
